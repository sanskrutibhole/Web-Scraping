# %%
import requests

# %% [markdown]
# # 1. Get a Title form the webpage

# %%
result = requests.get("http://example.com/")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text   #Code of HTML Website
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")   #to look good

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
site_paragarphs=soup.select("p")

# %%
site_paragarphs[0].getText()
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %% [markdown]
# # 2. Get List of contents form the wikipedia page

# %%
res= requests.get("https://en.wikipedia.org/wiki/Sudha_Murty")

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Sudha Murty - Wikipedia</title>
# ...

# %%
type(soup.select('.vector-toc-text'))
# Out:
# bs4.element.ResultSet

# %%
soup.select('.vector-toc-text')
# Out:
# [<div class="vector-toc-text">(Top)</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">1</span>Early life and education</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2</span>Career</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">3</span>Philanthropy</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">4</span>Personal life</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">5</span>Awards</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">6</span>Bibliography</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">6.1</span>Books</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">7</span>See also</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">8</span>References</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">9</span>External links</div>]

# %%
first_item = soup.select('.vector-toc-text')[0]

# %%
first_item
# Out:
# <div class="vector-toc-text">(Top)</div>

# %%
for item in soup.select('.vector-toc-text'):
    print(item.text)
# Out:
# (Top)
#
# 1Early life and education
#
# 2Career
#
# 3Philanthropy
#
# 4Personal life
#
# 5Awards
#
# 6Bibliography
#
# 6.1Books
#
# 7See also
#
# 8References
#
# 9External links

# %% [markdown]
# # 3. Get Images from the webpage

# %%
soup.select('.mw-file-element')
# Out:
# [<img alt="" class="mw-file-element" data-file-height="40" data-file-width="40" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" width="40"/>,
#  <img class="mw-file-element" data-file-height="378" data-file-width="283" decoding="async" height="294" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Sudha_Murthy_ji_in_2023.jpg/220px-Sudha_Murthy_ji_in_2023.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/9/9d/Sudha_Murthy_ji_in_2023.jpg 1.5x" width="220"/>,
# ...

# %%
image= soup.select('.mw-file-element')[1]

# %% [markdown]
# # 4. Get the image downloaded in your computer

# %%
image['src']  #get url of image
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Sudha_Murthy_ji_in_2023.jpg/220px-Sudha_Murthy_ji_in_2023.jpg'

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Sudha_Murthy_ji_in_2023.jpg/220px-Sudha_Murthy_ji_in_2023.jpg">

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Sudha_Murthy_ji_in_2023.jpg/220px-Sudha_Murthy_ji_in_2023.jpg')

# %%
#image_link.content (Binary code for image)
# Out:
# b'\xff\xd8\xff\xe1\x01HExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x07\x01\x0e\x00\x02\x00\x00\x00\xc2\x00\x00\x00b\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x01$\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x01,\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x01;\x00\x02\x00\x00\x00\x0b\x00\x00\x014\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x82\x98\x00\x02\x00\x00\x00\x04CLP\x00\x00\x00\x00\x00The President, Smt. Droupadi Murmu presenting the Padma Bhushan Award to Smt. Vani Jairam (Posthumous) at the Civil Investiture Ceremony-II at Rashtrapati Bhavan, in New Delhi on April 5, 2023.\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01Chhote Lal\x00\x00\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
f = open('my_computer_image.jpg','wb')

# %%
f.write(image_link.content)
# Out:
# 18471

# %%
f.close()
